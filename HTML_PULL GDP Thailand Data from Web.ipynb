# %%
import numpy as np
import pandas as pd

# %%
GDP_data = pd.read_html('https://tradingeconomics.com/thailand/gdp')

# %%
GDP_data[1]
# Out:
#                       Thailand GDP        Last    Previous     Highest  \
# 0                  GDP Growth Rate        0.40        0.20        9.40
# 1           GDP Annual Growth Rate        7.50       -2.60       15.50
# 2                              GDP      501.79      544.26      544.26
# 3              GDP Constant Prices  2525894.00  2717542.00  2750124.00
# 4           Gross National Product  2590352.00  2771187.00  2905359.00
# 5    Gross Fixed Capital Formation   656910.00   656869.00   713853.00
# 6                   GDP per capita     6094.43     6505.72     6505.72
# 7               GDP per capita PPP    17286.87    18453.47    18453.47
# 8             GDP From Agriculture   157432.00   168959.00   533055.00
# 9            GDP From Construction    87943.00    79515.00   103693.00
# 10          GDP From Manufacturing   703886.00   743594.00   743594.00
# 11                 GDP From Mining    52018.00    55962.00    63806.00
# ...
