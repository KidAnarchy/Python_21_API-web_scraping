# %% [markdown]
# ## Getting data from Web APIs

# %% [markdown]
# Some web site provide the WebAPIs which we can receive data using json object
# Try to click on this [link](https://api.github.com/repos/pandas-dev/pandas/issues)
#
# you will see the list of last 30 GitHub issue for pandas on Github,
# we can add read the data using the Python as given
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp =requests.get(url)
resp
# Out:
# <Response [200]>

# %% [markdown]
# The response object show the response code (200 means it is successfully downloaded)
#
# To read the data which come with it. Use the json method
#
# ![image.png](data:image/png;base64,...)

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43699',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43699/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43699/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43699/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43699',
#   'id': 1004370515,
#   'node_id': 'PR_kwDOAA0YD84sI5Kg',
#   'number': 43699,
#   'title': 'API: change ExtensionArray.astype to always return an ExtensionArray',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False,
#     'description': 'Extending pandas with custom dtypes or arrays.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-22T14:30:48Z',
#   'updated_at': '2021-09-22T14:30:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43699',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43699',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43699.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43699.patch'},
#   'body': "Closes #24877\r\n\r\nThis is a work-in-progress to see if it's realistic to require `ExtensionArray.astype` to always return an ExtensionArray (in practice this means returning a PandasArray if now a numpy array would be returned). \r\n\r\nFurther we will also need to see how this impacts external EAs, and how this change can be managed.\r\n\r\n(datetimelike and categorical arrays were not yet updated)",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43699/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43697',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43697/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43697/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43697/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43697',
#   'id': 1004121457,
#   'node_id': 'I_kwDOAA0YD8472a1x',
#   'number': 43697,
#   'title': 'BUG: idxmax raises when used with tuples',
#   'user': {'login': 'helgehatt',
#    'id': 12933913,
#    'node_id': 'MDQ6VXNlcjEyOTMzOTEz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12933913?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/helgehatt',
#    'html_url': 'https://github.com/helgehatt',
#    'followers_url': 'https://api.github.com/users/helgehatt/followers',
#    'following_url': 'https://api.github.com/users/helgehatt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/helgehatt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/helgehatt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/helgehatt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/helgehatt/orgs',
#    'repos_url': 'https://api.github.com/users/helgehatt/repos',
#    'events_url': 'https://api.github.com/users/helgehatt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/helgehatt/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-22T10:20:41Z',
#   'updated_at': '2021-09-22T10:20:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\nx = pd.Series([(1,3),(2,2),(3,1)])\r\n\r\n# This succeeds as the max operation is performed on the first element of a tuple\r\nassert x.max() == (3,1)\r\n\r\n# This fails with `TypeError: reduction operation 'argmax' not allowed for this dtype`\r\nassert x.idxmax() == 2\r\n\r\n# Using numpy directly works as you'd expect\r\nimport numpy as np\r\nassert np.argmax(x.values) == 2\n```\n\n\n### Issue Description\n\nUsing `max` on a series of tuples returns the tuple as if the max operation was performed on the first element of each tuple. \r\n\r\nUsing `idxmax` however, raises an operation not allowed TypeError.\n\n### Expected Behavior\n\nEven though there are several ways of achieving the desired result, I would expect consistency between the usage of `max` and `idxmax`, as it is for `max` and `argmax` in numpy.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 73c68257545b5f8530b7044f56647bd2db92e2ba\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.15.0-1113-azure\r\nVersion          : #126~16.04.1-Ubuntu SMP Tue Apr 13 16:55:24 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.3\r\nnumpy            : 1.20.1\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.1.3\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : 0.29.23\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : 7.22.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : 1.3.2\r\nfsspec           : 2021.06.0\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.4\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.2\r\nsqlalchemy       : None\r\ntables           : 3.6.1\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43697/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43695',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43695/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43695/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43695/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43695',
#   'id': 1003647840,
#   'node_id': 'PR_kwDOAA0YD84sGlw_',
#   'number': 43695,
#   'title': 'TYP: redundant imports for public API',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 59,
#    'closed_issues': 689,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-09-22T13:13:35Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2021-09-22T01:48:27Z',
#   'updated_at': '2021-09-22T13:58:20Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43695',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43695',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43695.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43695.patch'},
#   'body': '- [x] closes #43664\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43695/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43693',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43693/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43693/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43693/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43693',
#   'id': 1003491127,
#   'node_id': 'I_kwDOAA0YD8470A83',
#   'number': 43693,
#   'title': "BUG: to_numeric incorrectly converting values >= 16,777,217 with downcast='float'",
#   'user': {'login': 'jbencina',
#    'id': 5510940,
#    'node_id': 'MDQ6VXNlcjU1MTA5NDA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5510940?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbencina',
#    'html_url': 'https://github.com/jbencina',
#    'followers_url': 'https://api.github.com/users/jbencina/followers',
#    'following_url': 'https://api.github.com/users/jbencina/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbencina/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbencina/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbencina/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbencina/orgs',
#    'repos_url': 'https://api.github.com/users/jbencina/repos',
#    'events_url': 'https://api.github.com/users/jbencina/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbencina/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-09-21T23:41:37Z',
#   'updated_at': '2021-09-22T03:53:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### \r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the master branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\n# Series: Result 608202560.0\r\npd.to_numeric(pd.Series([608202549]), downcast='float')\r\n\r\n#Series: Result 608202560.0\r\npd.to_numeric(pd.Series([608202549.0]), downcast='float')\r\n\r\n# Single: Result 608202549\r\npd.to_numeric(608202549, downcast='float')\r\n\r\n# List: Result array([608202560, 608202560])\r\npd.to_numeric([608202548, 608202549], downcast='float').astype(int)\r\n\r\n# Range: 1st issue at 16777217\r\narr = np.arange(0, 6e8, dtype='int64')\r\na = pd.Series(arr)\r\nb = pd.to_numeric(a, downcast='float').astype(int)\r\nnp.where(a != b)[0]\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nWhen attempting to use `to_numeric()` on a Pandas Series or list with values >= 16777217, the resulting float is not expected given the input number.\r\n\r\n```python\r\npd.to_numeric(pd.Series([608202549]), downcast='float')\r\n0    608202560.0 \r\n\r\n>>> pd.to_numeric(pd.Series([608202549.0]), downcast='float')\r\n0    608202560.0\r\n```\r\n\r\nThis behavior does not occur if the value is passed as a scalar, but does also appear if a List is passed. By comparing values within a range, it seems the issue starts from 16,777,217 onward. This seems to have roots in the discussion about 32 bit floating point in this [Stack Overflow](https://github.com/pandas-dev/pandas/issues/23676#issuecomment-438488603) as well as another Pandas issue on float issues with rank #18271\r\n\r\n**Edit-** I updated this issue to be clear that this is affecting both integers and floats larger than 16,777,217\r\n\r\n### Expected Behavior\r\n\r\n`to_numeric()` should yield the same functional number in float form as the original value(s)\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n>>> pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 73c68257545b5f8530b7044f56647bd2db92e2ba\r\npython           : 3.9.4.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.6.0\r\nVersion          : Darwin Kernel Version 20.6.0: Wed Jun 23 00:26:27 PDT 2021; root:xnu-7195.141.2~5/RELEASE_ARM64_T8101\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.3\r\nnumpy            : 1.21.2\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.0.1\r\nsetuptools       : 54.2.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43693/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43690',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43690/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43690/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43690/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43690',
#   'id': 1003303929,
#   'node_id': 'PR_kwDOAA0YD84sFY-U',
#   'number': 43690,
#   'title': 'BUG: Write compliant Parquet with `pyarrow`',
#   'user': {'login': 'judahrand',
#    'id': 17158624,
#    'node_id': 'MDQ6VXNlcjE3MTU4NjI0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17158624?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/judahrand',
#    'html_url': 'https://github.com/judahrand',
#    'followers_url': 'https://api.github.com/users/judahrand/followers',
#    'following_url': 'https://api.github.com/users/judahrand/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/judahrand/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/judahrand/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/judahrand/subscriptions',
#    'organizations_url': 'https://api.github.com/users/judahrand/orgs',
#    'repos_url': 'https://api.github.com/users/judahrand/repos',
#    'events_url': 'https://api.github.com/users/judahrand/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/judahrand/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 685114413,
#     'node_id': 'MDU6TGFiZWw2ODUxMTQ0MTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet',
#     'name': 'IO Parquet',
#     'color': '5319e7',
#     'default': False,
#     'description': 'parquet, feather'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2021-09-21T21:21:09Z',
#   'updated_at': '2021-09-22T13:08:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43690',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43690',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43690.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43690.patch'},
#   'body': '- [x] closes #43689\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43690/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43689',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43689/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43689/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43689/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43689',
#   'id': 1003294224,
#   'node_id': 'I_kwDOAA0YD847zQ4Q',
#   'number': 43689,
#   'title': 'BUG: `DataFrame().to_parquet()` does not write Parquet compliant data for nested arrays',
#   'user': {'login': 'judahrand',
#    'id': 17158624,
#    'node_id': 'MDQ6VXNlcjE3MTU4NjI0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17158624?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/judahrand',
#    'html_url': 'https://github.com/judahrand',
#    'followers_url': 'https://api.github.com/users/judahrand/followers',
#    'following_url': 'https://api.github.com/users/judahrand/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/judahrand/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/judahrand/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/judahrand/subscriptions',
#    'organizations_url': 'https://api.github.com/users/judahrand/orgs',
#    'repos_url': 'https://api.github.com/users/judahrand/repos',
#    'events_url': 'https://api.github.com/users/judahrand/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/judahrand/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 685114413,
#     'node_id': 'MDU6TGFiZWw2ODUxMTQ0MTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet',
#     'name': 'IO Parquet',
#     'color': '5319e7',
#     'default': False,
#     'description': 'parquet, feather'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 59,
#    'closed_issues': 689,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2021-09-22T13:13:35Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2021-09-21T21:13:43Z',
#   'updated_at': '2021-09-22T13:08:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### \r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the master branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pyarrow as pa\r\nimport pyarrow.parquet as pq\r\nimport pandas as pd\r\n\r\n\r\ndf = pd.DataFrame({\'int_array_col\': [[[1,2,3]], [[4,5,6]]]})\r\ndf.to_parquet(\'/tmp/test\', engine=\'pyarrow\')\r\n\r\npandas_parquet_table = pq.read_table(\'/tmp/test\')\r\n\r\npyarrow_table = pa.Table.from_pandas(df)\r\nwriter = pa.BufferOutputStream()\r\npq.write_table(\r\n    pyarrow_table,\r\n    writer,\r\n    use_compliant_nested_type=True\r\n)\r\nreader = pa.BufferReader(writer.getvalue())\r\nparquet_table = pq.read_table(reader)\r\n\r\nprint("Pandas:", pandas_parquet_table.schema.types)\r\nprint("Non-compliant Parquet:", pyarrow_table.schema.types)\r\nprint("Compliant Parquet:", parquet_table.schema.types)\r\nassert pandas_parquet_table.schema.types == pyarrow_table.types\r\nassert pandas_parquet_table.schema.types == parquet_table.schema.types\r\n\r\n\r\n```python-traceback\r\nPandas: [ListType(list<item: list<item: int64>>)]\r\nNon-compliant Parquet: [ListType(list<item: list<item: int64>>)]\r\nCompliant Parquet: [ListType(list<element: list<element: int64>>)]\r\nTraceback (most recent call last):\r\n  File "/Users/judahrand/test_dir/pandas_parquet.py", line 25, in <module>\r\n    assert pandas_parquet_table.schema.types == parquet_table.schema.types\r\nAssertionError\r\n```\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThis method currently does not write adherent Parquet Logical Types for nested arrays as defined (here)[https://github.com/apache/parquet-format/blob/master/LogicalTypes.md#nested-types]. This can cause problems when trying to Parquet as in intermediate format, for example loading data into BigQuery which expects adherent data.\r\n\r\nThis was an issue in PyArrow itself, however, it was fixed in (ARROW-11497)[https://github.com/apache/arrow/pull/9489]. I believe that this flag should be set in Pandas if we are to claim that Pandas `.to_parquet()` method actually outputs Parquet.\r\n\r\n### Expected Behavior\r\n\r\nOutput complaint Parquet.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nReplace this line with the output of pd.show_versions()\r\n\r\n</details>\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43689/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43686',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43686/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43686/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43686/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43686',
#   'id': 1003138016,
#   'node_id': 'PR_kwDOAA0YD84sE0p8',
#   'number': 43686,
#   'title': 'CLN: simplify `Styler._translate`',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-21T19:33:07Z',
#   'updated_at': '2021-09-21T20:08:41Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43686',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43686',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43686.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43686.patch'},
#   'body': 'Bit of a pre cursor to some other cleaning in #43649.\r\nPrevents needing to pass variables around in worker functions, and has the added benefit of making the CSS classes user editable.\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43686/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43682',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43682/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43682/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43682/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43682',
#   'id': 1002839181,
#   'node_id': 'I_kwDOAA0YD847xhyN',
#   'number': 43682,
#   'title': 'ENH: generic implementation of ea_wrap_cython_operation',
#   'user': {'login': 'debnathshoham',
#    'id': 6472290,
#    'node_id': 'MDQ6VXNlcjY0NzIyOTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6472290?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/debnathshoham',
#    'html_url': 'https://github.com/debnathshoham',
#    'followers_url': 'https://api.github.com/users/debnathshoham/followers',
#    'following_url': 'https://api.github.com/users/debnathshoham/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/debnathshoham/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/debnathshoham/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/debnathshoham/subscriptions',
#    'organizations_url': 'https://api.github.com/users/debnathshoham/orgs',
#    'repos_url': 'https://api.github.com/users/debnathshoham/repos',
#    'events_url': 'https://api.github.com/users/debnathshoham/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/debnathshoham/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False,
#     'description': 'Extending pandas with custom dtypes or arrays.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1075,
#    'closed_issues': 777,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2021-09-21T18:02:52Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-09-21T16:40:03Z',
#   'updated_at': '2021-09-21T18:03:03Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'Create a property function to decide what to do for EAs in `_ea_wrap_cython_operation` for groupby ops.\r\nxref : https://github.com/pandas-dev/pandas/pull/43634#discussion_r712140219\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/439acc99b2968ec8062eee05af7346acea20915b/pandas/core/groupby/ops.py#L318-L333',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43682/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43681',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43681/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43681/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43681/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43681',
#   'id': 1002416036,
#   'node_id': 'I_kwDOAA0YD847v6ek',
#   'number': 43681,
#   'title': 'BUG: groupby/apply reuses the index which causes weird behavior',
#   'user': {'login': 'sdementen',
#    'id': 1304950,
#    'node_id': 'MDQ6VXNlcjEzMDQ5NTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1304950?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sdementen',
#    'html_url': 'https://github.com/sdementen',
#    'followers_url': 'https://api.github.com/users/sdementen/followers',
#    'following_url': 'https://api.github.com/users/sdementen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sdementen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sdementen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sdementen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sdementen/orgs',
#    'repos_url': 'https://api.github.com/users/sdementen/repos',
#    'events_url': 'https://api.github.com/users/sdementen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sdementen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-09-21T12:49:03Z',
#   'updated_at': '2021-09-21T13:01:07Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas\r\n\r\ndf = pandas.DataFrame(index=list(range(10)), columns=list("ABC"), data=1)\r\nl = []\r\nprint(df.groupby(df.index < 4).apply(lambda col: l.append(col.index) or id(col.index)))\r\nprint(l)\r\n\r\nsr = pandas.Series(index=list(range(10)), data=1)\r\nl = []\r\nprint(sr.groupby(sr.index < 4).apply(lambda col: l.append(col.index) or id(col.index)))\r\nprint(l[0])\r\nprint(l[1])\r\n\r\n\r\ndf = pandas.DataFrame(index=list(range(10)), columns=list("ABC"), data=1)\r\nl = []\r\nprint(df.groupby(df.index < 4).apply(lambda col: l.append(col.eval("index*2")) or id(col.index)))\r\nprint(l[0])\r\nprint(l[1])\r\nprint(len(l[0]),l[0].shape)\n```\n\n\n### Issue Description\n\nThe result for the Dataframe is quite puzzling as it appears the index of the column sent to the lambda is reused/mutated across the different calls of the groupby/apply (while this does not happend on the Series). I think the values object is also shared.\r\nEven worse, when using the column to generate new Series, we see that as the index is shared, we end up with a Series (`l[0]` in the example) which a shape that is not consistent with the length of the Series.\r\n\r\n```\r\nFalse    2116454933648\r\nTrue     2116454933648\r\ndtype: int64\r\n[Int64Index([0, 1, 2, 3], dtype=\'int64\'), Int64Index([0, 1, 2, 3], dtype=\'int64\')]\r\nFalse    2116454934224\r\nTrue     2116454934464\r\ndtype: int64\r\nInt64Index([4, 5, 6, 7, 8, 9], dtype=\'int64\')\r\nInt64Index([0, 1, 2, 3], dtype=\'int64\')\r\nFalse    2116454933456\r\nTrue     2116454933456\r\ndtype: int64\r\n0     8\r\n1    10\r\n2    12\r\n3    14\r\n     16\r\n     18\r\ndtype: int64\r\n0    0\r\n1    2\r\n2    4\r\n3    6\r\ndtype: int64\r\n4 (6,)\r\n```\n\n### Expected Behavior\n\nI would expect a similar result as for Series, ie having a different index/values object on each call of the lambda function for the Dataframe.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 5f648bf1706dd75a9ca0d29f26eadfbb595fe52b\r\npython           : 3.9.5.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.18363\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : French_Belgium.1252\r\npandas           : 1.3.2\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.2.4\r\nsetuptools       : 58.0.0\r\nCython           : None\r\npytest           : 6.2.5\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : 4.10.0\r\nbottleneck       : None\r\nfsspec           : 2021.08.1\r\nfastparquet      : 0.7.1\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.7\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.3\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : 0.17.0\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43681/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43678',
#   'id': 1001672010,
#   'node_id': 'PR_kwDOAA0YD84r_48U',
#   'number': 43678,
#   'title': 'POC: New UDF methods option',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-21T01:59:24Z',
#   'updated_at': '2021-09-21T13:24:01Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43678',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43678',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43678.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43678.patch'},
#   'body': "Start of #41112\r\n\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nThe goal is to provide an implementation for apply on lists. See https://github.com/pandas-dev/pandas/issues/41112#issuecomment-902366002 for why this necessitates a change to agg behavior for lists. It is possible to break this up into several PRs, but wanted to give a view as to what it would appear in totality.\r\n\r\nAttached is a notebook demonstrating the differences in behavior (github doesn't allow attaching the notebook directly).\r\n\r\n[udfs.pdf](https://github.com/pandas-dev/pandas/files/7199652/udfs.pdf)\r\n\r\n",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43674',
#   'id': 1001369179,
#   'node_id': 'PR_kwDOAA0YD84r-5Vl',
#   'number': 43674,
#   'title': 'TST: dropping of nuisance columns for groupby ops #38815',
#   'user': {'login': 'horaceklai',
#    'id': 44500643,
#    'node_id': 'MDQ6VXNlcjQ0NTAwNjQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44500643?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/horaceklai',
#    'html_url': 'https://github.com/horaceklai',
#    'followers_url': 'https://api.github.com/users/horaceklai/followers',
#    'following_url': 'https://api.github.com/users/horaceklai/following{/other_user}',
# ...
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43650/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43650/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43650',
#   'id': 1000133222,
#   'node_id': 'I_kwDOAA0YD847nNJm',
#   'number': 43650,
#   'title': 'CI/BUG: pyarrow read_csv deadlock',
#   'user': {'login': 'mzeitlin11',
#    'id': 37011898,
#    'node_id': 'MDQ6VXNlcjM3MDExODk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37011898?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mzeitlin11',
#    'html_url': 'https://github.com/mzeitlin11',
#    'followers_url': 'https://api.github.com/users/mzeitlin11/followers',
#    'following_url': 'https://api.github.com/users/mzeitlin11/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mzeitlin11/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mzeitlin11/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mzeitlin11/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mzeitlin11/orgs',
#    'repos_url': 'https://api.github.com/users/mzeitlin11/repos',
#    'events_url': 'https://api.github.com/users/mzeitlin11/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mzeitlin11/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-09-18T21:00:27Z',
#   'updated_at': '2021-09-21T23:41:09Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "xref #43611, #43643\r\n\r\nWhen trying to figure out azure timeout issues, deadlock appeared to be occurring in parser code, so `pyarrow` makes sense as the culprit. Seems like tests with weird input cause issues, for example some of the `parse_dates` tests, or for a specific reproducer the test:\r\n\r\n`pandas/tests/io/parser/common/test_ints.py::test_outside_int64_uint64_range`\r\n\r\nOn current `pyarrow` I can't reproduce, but azure uses 0.17.0, with which can reproduce a deadlock (just running the command `pandas/tests/io/parser/common/test_ints.py::test_outside_int64_uint64_range`) on macOS. Doesn't happen consistently, but will deadlock (to the point that need to sigkill to stop, which explains why `pytest-timeout` didn't catch it).\r\n\r\ncc @lithomas1 if any thoughts here",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43650/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43649',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43649/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43649/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43649/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43649',
#   'id': 1000130281,
#   'node_id': 'PR_kwDOAA0YD84r7S-E',
#   'number': 43649,
#   'title': 'BUG: styler multiindex hiding indexes and columns alignment',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57395487,
#     'node_id': 'MDU6TGFiZWw1NzM5NTQ4Nw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20HTML',
#     'name': 'IO HTML',
#     'color': '006b75',
#     'default': False,
#     'description': 'read_html, to_html, Styler.apply, Styler.applymap'},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-18T20:45:11Z',
#   'updated_at': '2021-09-21T20:10:54Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43649',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43649',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43649.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43649.patch'},
#   'body': "- [x] closes #43637 #43644\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] <s>whatsnew entry</s> not needed?\r\n\r\nThe key change made here was to add a single line: `if r not in self.hidden_rows: (line 500)` in the loop.\r\nGithub makes it look like there are a lot more changes.\r\n\r\n`_translate_latex` then needed updating due to the different generation of the object that is input to it.\r\n\r\nAnd tests were update and comprehensive tests for the issues added.\r\n\r\nAlso **closes** the prs #43638  #43640.\r\n\r\nI don't think this requires a whatsnew since the bug seems to have been created by hiding `levels` which is a new feature in 1.4.0.",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43649/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43644',
#   'id': 1000092558,
#   'node_id': 'I_kwDOAA0YD847nDOO',
#   'number': 43644,
#   'title': 'BUG: styler hide_index hide_columns misaligns multiindex',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57395487,
#     'node_id': 'MDU6TGFiZWw1NzM5NTQ4Nw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20HTML',
#     'name': 'IO HTML',
#     'color': '006b75',
#     'default': False,
#     'description': 'read_html, to_html, Styler.apply, Styler.applymap'},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-18T17:44:49Z',
#   'updated_at': '2021-09-19T19:45:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nmidx = MultiIndex.from_product([["A", "B"], ["a", "b"], ["X", "Y"]], names=["zero", "one", "two"])\r\ncidx = MultiIndex.from_product([["a", "b"], ["C", "D"], ["V", "W"]], names=["zero", "one", "two"])\r\ndf = DataFrame(np.arange(64).reshape(8,8), index=midx, columns=cidx)\r\nstyler = Styler(df)\r\nstyler.hide_index(level=1).hide_columns(level=0)\r\nstyler.hide_index([("A", "a", "X"), ("A", "b", "X")])\r\nstyler.hide_columns([("a", "C", "W"), ("a", "D", "V")])\r\nstyler\n```\n\n\n### Issue Description\n\nWhen using a MultiIndex and combining with hiding different levels and hiding specific rows/columns, some bugs appear.\r\n\r\nOutput is quite strange on second row for HTML output.\r\n\r\n![Screen Shot 2021-09-18 at 19 40 34](https://user-images.githubusercontent.com/24256554/133897657-0e500e82-d1ae-4098-9d19-c194dbcc58fc.png)\r\n\r\nAlso using LaTeX output:  \r\n```\r\n>>> styler.to_latex()\r\n\\begin{tabular}{llrrrrrr}\r\n & one & C & D & \\multicolumn{2}{r}{C} & \\multicolumn{2}{r}{D} \\\\\r\n & two & V & W & V & W & V & W \\\\\r\nzero & two &  &  &  &  &  &  \\\\\r\n\\multirow[c]{2}{*}{A} &  & Y & 8 & 11 & 12 & 13 & 14 & 15 \\\\\r\n &  & Y & 24 & 27 & 28 & 29 & 30 & 31 \\\\\r\n\\multirow[c]{4}{*}{B} & \\multirow[c]{2}{*}{} & X & 32 & 35 & 36 & 37 & 38 & 39 \\\\\r\n &  & Y & 40 & 43 & 44 & 45 & 46 & 47 \\\\\r\n & \\multirow[c]{2}{*}{} & X & 48 & 51 & 52 & 53 & 54 & 55 \\\\\r\n &  & Y & 56 & 59 & 60 & 61 & 62 & 63 \\\\\r\n\\end{tabular}\r\n```\r\n\r\nThe above is a LaTeX error but if the number of columns is expanded to 9 then it renders like:\r\n![Screen Shot 2021-09-18 at 19 43 51](https://user-images.githubusercontent.com/24256554/133897745-30a2eb1c-80e3-4e7c-8bd7-c3765ef973f6.png)\r\n\r\n\n\n### Expected Behavior\n\nClearly we want to align all the datapoints and have the hidden levels correctly hidden.\n\n### Installed Versions\n\nmaster\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43642',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43642/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43642/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43642/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43642',
#   'id': 1000075620,
#   'node_id': 'PR_kwDOAA0YD84r7Kxl',
#   'number': 43642,
#   'title': 'CLN: Python Parser code',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-18T16:26:11Z',
#   'updated_at': '2021-09-21T19:16:08Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43642',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43642',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43642.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43642.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43642/timeline',
#   'performed_via_github_app': None}]

# %%
data[0]['title']
# Out:
# 'API: change ExtensionArray.astype to always return an ExtensionArray'

# %%
issues = pd.DataFrame(data, columns=['number','title',
                                    'labels','state'])

# %%
issues.head(10)
# Out:
#    number                                              title  \
# 0   43699  API: change ExtensionArray.astype to always re...
# 1   43697           BUG: idxmax raises when used with tuples
# 2   43695              TYP: redundant imports for public API
# 3   43693  BUG: to_numeric incorrectly converting values ...
# 4   43690        BUG: Write compliant Parquet with `pyarrow`
# 5   43689  BUG: `DataFrame().to_parquet()` does not write...
# 6   43686                  CLN: simplify `Styler._translate`
# 7   43682  ENH: generic implementation of ea_wrap_cython_...
# 8   43681  BUG: groupby/apply reuses the index which caus...
# 9   43678                        POC: New UDF methods option
#
#                                               labels state
# 0  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 1  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 3  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 5  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 6                                                 []  open
# 7  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 8  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open

# %%
#Export file in CSV

# issues.to_csv('example/out2.csv')
