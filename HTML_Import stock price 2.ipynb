# %%
import numpy as np
import pandas as pd

# %%
import pandas_datareader.data as web
from datetime import datetime

# %%
# PRICENPQUSDM

rice = web.get_data_fred('PRICENPQUSDM')

print(rice)
# Out:
#             PRICENPQUSDM
# DATE
# 2016-10-01    367.666667
# 2016-11-01    360.818182
# 2016-12-01    367.545455
# 2017-01-01    372.545455
# 2017-02-01    368.500000
# 2017-03-01    367.782609
# 2017-04-01    374.500000
# 2017-05-01    402.913043
# 2017-06-01    444.681818
# 2017-07-01    419.952381
# 2017-08-01    405.652174
# 2017-09-01    413.142857
# 2017-10-01    407.227273
# 2017-11-01    404.045455
# 2017-12-01    407.952381
# 2018-01-01    422.304348
# 2018-02-01    417.850000
# 2018-03-01    409.772727
# 2018-04-01    432.380952
# 2018-05-01    433.217391
# 2018-06-01    413.142857
# 2018-07-01    378.681818
# 2018-08-01    383.434783
# 2018-09-01    383.000000
# 2018-10-01    392.043478
# 2018-11-01    390.818182
# 2018-12-01    380.333333
# 2019-01-01    383.739130
# 2019-02-01    390.550000
# 2019-03-01    383.142857
# 2019-04-01    397.409091
# 2019-05-01    390.304348
# 2019-06-01    396.250000
# 2019-07-01    395.956522
# 2019-08-01    414.681818
# ...
